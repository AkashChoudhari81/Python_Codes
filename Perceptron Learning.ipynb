# %%
import numpy as np
import matplotlib.pyplot as plt

X = np.array([
    [0,0],
    [0,1],
    [1,0],
    [1,1]])
Y = np.array([[0],[0],[0],[1]])

class Perceptron:
    def __init__(self):
        self.weights = np.zeros(2)
        self.bias = 0.75

    def activation(self,x):
        return 1 if x>= 0 else 0

    def predict(self,x):
        return self.activation(np.dot(x,self.weights) + self.bias)

    def train(self,X,Y,lr = 0.1, epochs = 10):
        for _ in range(epochs):
            for xi,target in zip(X,Y):
                pred = self.predict(xi)
                error = target - pred
                self.weights += lr * error * xi
                self.bias += lr * error

model = Perceptron()
model.train(X,Y)

for i in range(len(X)):
    color = 'red' if Y[i] ==1 else 'blue'
    plt.scatter(X[i][0],X[i][1],color = color)

x_vals = np.array([X[:,0].min()-1,X[:,0].max()+1])
y_vals = (-model.weights[0] * x_vals - model.bias)/model.weights[1]
plt.plot(x_vals,y_vals,'k--',label = 'Decision Boundary')





plt.xlabel("X1")
plt.ylabel("X2")
plt.grid(True)
plt.title("Decision Boundray using Perceptron Learning")
# Out:
# Text(0.5, 1.0, 'Decision Boundray using Perceptron Learning')

# %%
import tensorflow as tf
from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,LabelEncoder
import numpy as np

# %%
iris = datasets.load_iris()

X = iris.data
Y = iris.target

# %% [raw]
# encoder = LabelEncoder()
# Y = encoder.fit_transform(Y)

# %%
scaler = StandardScaler()
Y = scaler
